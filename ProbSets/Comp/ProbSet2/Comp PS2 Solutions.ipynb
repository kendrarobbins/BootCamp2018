# %% [markdown]
# # Comp ProbSet2

# %% [markdown]
# Kendra Robbins

# %% [markdown]
# ## Introduction to Matplotlib

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Problem 1

# %%
def prob1(n):
    
    A = np.random.normal(size=(n,n))
    print(A)
    
    B = np.mean(A, axis=0)
    
    C = np.var(B)
    
    return C

# %% [markdown]
# Problem 2

# %%
np.pi = p

# %%
x=np.linspace(-2*p, 2*p, 100)

# %%
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.arctan(x))

# %% [markdown]
# Problem 3 - incomplete
# how do i plot 2 functions in 1 plot? why do my plots look wrong?

# %%
D1 = np.linspace(-2, .99999999, 60)

# %%
D2 = np.linspace(1.000000001,6, 50)

# %%
E1 = 1/(D1-1)

# %%
F1 = plt.plot(D1, E1)

# %%
E2 = 1/(D2-1)

# %%
F2 = plt.plot(D2, E2)

# %%
plt.show(F1,F2)

# %% [markdown]
# Problem 4
